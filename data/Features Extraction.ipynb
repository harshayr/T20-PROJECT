# %% [markdown]
# # Creating new features

# %%
import pandas as pd
import numpy as np
import pickle
import warnings 
warnings.filterwarnings('ignore')

# %%
matches = pickle.load(open('data_extraction_1','rb'))
matches
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2  West Indies        India   0.1     0                0
# 1           2  West Indies        India   0.2     0      JD Campbell
# 2           2  West Indies        India   0.3     0                0
# 3           2  West Indies        India   0.4     1                0
# 4           2  West Indies        India   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 118       964     Pakistan  New Zealand  19.2     1                0
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf
# 120       964     Pakistan  New Zealand  19.4     2                0
# 121       964     Pakistan  New Zealand  19.5     1                0
# 122       964     Pakistan  New Zealand  19.6     1                0
#
#            city                                              venue
# 0    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 1    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 2    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 3    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 4    Lauderhill  Central Broward Regional Park Stadium Turf Ground
# ..          ...                                                ...
# 118    Auckland                                          Eden Park
# 119    Auckland                                          Eden Park
# 120    Auckland                                          Eden Park
# 121    Auckland                                          Eden Park
# 122    Auckland                                          Eden Park
#
# [66280 rows x 8 columns]

# %%
# We are going to create some new feature

# %%
# required columns

# batting team
# bowling team
# current run rate
# wickets left
# city
# venue
# last five overs run
# ball left

# %%
matches.isna().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8919
# venue                  0
# dtype: int64

# %%
# As you can see there are some missing values in city columns so we are going to replace those values with venue

# %%
matches[matches['city'].isna()]['venue'].value_counts()  # we can use 1st word of venue to replace those values as a city
# Out:
# venue
# Dubai International Cricket Stadium        3340
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(matches['city'],matches['venue'].str.split().apply(lambda x: x[0]),matches['city'])  # 
# it will use 1st word of venue as city

# %%
matches['city'] = cities

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2  West Indies        India   0.1     0                0  Central
# 1           2  West Indies        India   0.2     0      JD Campbell  Central
# 2           2  West Indies        India   0.3     0                0  Central
# 3           2  West Indies        India   0.4     1                0  Central
# 4           2  West Indies        India   0.5     0                0  Central
# ..        ...          ...          ...   ...   ...              ...      ...
# 118       964     Pakistan  New Zealand  19.2     1                0     Eden
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf     Eden
# 120       964     Pakistan  New Zealand  19.4     2                0     Eden
# 121       964     Pakistan  New Zealand  19.5     1                0     Eden
# 122       964     Pakistan  New Zealand  19.6     1                0     Eden
#
#                                                  venue
# 0    Central Broward Regional Park Stadium Turf Ground
# 1    Central Broward Regional Park Stadium Turf Ground
# 2    Central Broward Regional Park Stadium Turf Ground
# 3    Central Broward Regional Park Stadium Turf Ground
# 4    Central Broward Regional Park Stadium Turf Ground
# ..                                                 ...
# 118                                          Eden Park
# 119                                          Eden Park
# 120                                          Eden Park
# 121                                          Eden Park
# 122                                          Eden Park
#
# [66280 rows x 8 columns]

# %%
matches.drop(columns = 'venue', inplace = True)

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city
# 0           2  West Indies        India   0.1     0                0  Central
# 1           2  West Indies        India   0.2     0      JD Campbell  Central
# 2           2  West Indies        India   0.3     0                0  Central
# 3           2  West Indies        India   0.4     1                0  Central
# 4           2  West Indies        India   0.5     0                0  Central
# ..        ...          ...          ...   ...   ...              ...      ...
# 118       964     Pakistan  New Zealand  19.2     1                0     Eden
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf     Eden
# 120       964     Pakistan  New Zealand  19.4     2                0     Eden
# 121       964     Pakistan  New Zealand  19.5     1                0     Eden
# 122       964     Pakistan  New Zealand  19.6     1                0     Eden
#
# [66280 rows x 7 columns]

# %%
matches['city'].value_counts()   # these are the number of balls in each city 3933/120 = total matches
# Out:
# city
# Shere      3933
# Eden       3499
# Dubai      3340
# R          2983
# New        2819
#            ...
# Sardar      121
# Subrata     121
# Hagley      121
# Grange      121
# Carrara      64
# Name: count, Length: 90, dtype: int64

# %%
# we are going to consider those cities where number of marches is greater than 5 i.e number of balls greater than 600

# %%
matches['city'].value_counts()[matches['city'].value_counts()>600].shape   # unique cities where atleast five matches played
# Out:
# (34,)

# %%
matches['city'].value_counts()[matches['city'].value_counts()>600].sum()  # 51286 these data points will left after removing less matches cities
# Out:
# 51286

# %%
a = list(matches['city'].value_counts()[matches['city'].value_counts()>600].index)

# %%
matches = matches[matches['city'].isin(a)]

# %%
matches.shape
# Out:
# (51286, 7)

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city
# 0           2  West Indies        India   0.1     0                0  Central
# 1           2  West Indies        India   0.2     0      JD Campbell  Central
# 2           2  West Indies        India   0.3     0                0  Central
# 3           2  West Indies        India   0.4     1                0  Central
# 4           2  West Indies        India   0.5     0                0  Central
# ..        ...          ...          ...   ...   ...              ...      ...
# 118       964     Pakistan  New Zealand  19.2     1                0     Eden
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf     Eden
# 120       964     Pakistan  New Zealand  19.4     2                0     Eden
# 121       964     Pakistan  New Zealand  19.5     1                0     Eden
# 122       964     Pakistan  New Zealand  19.6     1                0     Eden
#
# [51286 rows x 7 columns]

# %%
matches['current_score'] = matches.groupby('match_id')['runs'].cumsum() # calculating current_score for each match 
# after each match current_score will set to zero because we use groupby on match id for defining match and runs for cumsum()

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2  West Indies        India   0.1     0                0  Central
# 1           2  West Indies        India   0.2     0      JD Campbell  Central
# 2           2  West Indies        India   0.3     0                0  Central
# 3           2  West Indies        India   0.4     1                0  Central
# 4           2  West Indies        India   0.5     0                0  Central
# ..        ...          ...          ...   ...   ...              ...      ...
# 118       964     Pakistan  New Zealand  19.2     1                0     Eden
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf     Eden
# 120       964     Pakistan  New Zealand  19.4     2                0     Eden
# 121       964     Pakistan  New Zealand  19.5     1                0     Eden
# 122       964     Pakistan  New Zealand  19.6     1                0     Eden
#
#      current_score
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1
# ..             ...
# 118            149
# 119            149
# 120            151
# 121            152
# 122            153
#
# [51286 rows x 8 columns]

# %%
# creating column by spliting ball column for over and ball_no

# %%
matches['over'] = matches['ball'].apply(lambda x: str(x).split('.')[0])
matches['ball_no'] = matches['ball'].apply(lambda x: str(x).split('.')[1])

# %%
# Creating ball_left 
matches["balls_left"] = 120-(matches['over'].astype(int)*6 + matches["ball_no"].astype(int))

# %%
matches["balls_left"] = matches["balls_left"].apply(lambda x: 0 if x<0 else 0)   # if there os any extra ball in over

# %%
matches["balls_bowled"] = (matches['over'].astype(int)*6 + matches["ball_no"].astype(int))

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2  West Indies        India   0.1     0                0  Central
# 1           2  West Indies        India   0.2     0      JD Campbell  Central
# 2           2  West Indies        India   0.3     0                0  Central
# 3           2  West Indies        India   0.4     1                0  Central
# 4           2  West Indies        India   0.5     0                0  Central
# ..        ...          ...          ...   ...   ...              ...      ...
# 118       964     Pakistan  New Zealand  19.2     1                0     Eden
# 119       964     Pakistan  New Zealand  19.3     0    Faheem Ashraf     Eden
# 120       964     Pakistan  New Zealand  19.4     2                0     Eden
# 121       964     Pakistan  New Zealand  19.5     1                0     Eden
# 122       964     Pakistan  New Zealand  19.6     1                0     Eden
#
#      current_score over ball_no  balls_left  balls_bowled
# 0                0    0       1           0             1
# 1                0    0       2           0             2
# 2                0    0       3           0             3
# 3                1    0       4           0             4
# 4                1    0       5           0             5
# ..             ...  ...     ...         ...           ...
# 118            149   19       2           0           116
# 119            149   19       3           0           117
# 120            151   19       4           0           118
# 121            152   19       5           0           119
# 122            153   19       6           0           120
#
# [51286 rows x 12 columns]

# %%
matches['player_dismissed'] = matches['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2  West Indies        India   0.1     0                 0
# 1           2  West Indies        India   0.2     0                 1
# 2           2  West Indies        India   0.3     0                 0
# 3           2  West Indies        India   0.4     1                 0
# 4           2  West Indies        India   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 118       964     Pakistan  New Zealand  19.2     1                 0
# 119       964     Pakistan  New Zealand  19.3     0                 1
# 120       964     Pakistan  New Zealand  19.4     2                 0
# 121       964     Pakistan  New Zealand  19.5     1                 0
# 122       964     Pakistan  New Zealand  19.6     1                 0
#
#         city  current_score over ball_no  balls_left  balls_bowled
# 0    Central              0    0       1           0             1
# 1    Central              0    0       2           0             2
# 2    Central              0    0       3           0             3
# 3    Central              1    0       4           0             4
# 4    Central              1    0       5           0             5
# ..       ...            ...  ...     ...         ...           ...
# 118     Eden            149   19       2           0           116
# 119     Eden            149   19       3           0           117
# 120     Eden            151   19       4           0           118
# 121     Eden            152   19       5           0           119
# 122     Eden            153   19       6           0           120
#
# [51286 rows x 12 columns]

# %%
matches['player_dismissed'] = matches.groupby('match_id')['player_dismissed'].cumsum()

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2  West Indies        India   0.1     0                 0
# 1           2  West Indies        India   0.2     0                 1
# 2           2  West Indies        India   0.3     0                 1
# 3           2  West Indies        India   0.4     1                 1
# 4           2  West Indies        India   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 118       964     Pakistan  New Zealand  19.2     1                 8
# 119       964     Pakistan  New Zealand  19.3     0                 9
# 120       964     Pakistan  New Zealand  19.4     2                 9
# 121       964     Pakistan  New Zealand  19.5     1                 9
# 122       964     Pakistan  New Zealand  19.6     1                 9
#
#         city  current_score over ball_no  balls_left  balls_bowled
# 0    Central              0    0       1           0             1
# 1    Central              0    0       2           0             2
# 2    Central              0    0       3           0             3
# 3    Central              1    0       4           0             4
# 4    Central              1    0       5           0             5
# ..       ...            ...  ...     ...         ...           ...
# 118     Eden            149   19       2           0           116
# 119     Eden            149   19       3           0           117
# 120     Eden            151   19       4           0           118
# 121     Eden            152   19       5           0           119
# 122     Eden            153   19       6           0           120
#
# [51286 rows x 12 columns]

# %%
matches['wickets_left'] = 10-matches['player_dismissed']

# %%
matches
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2  West Indies        India   0.1     0                 0
# 1           2  West Indies        India   0.2     0                 1
# 2           2  West Indies        India   0.3     0                 1
# 3           2  West Indies        India   0.4     1                 1
# 4           2  West Indies        India   0.5     0                 1
# ..        ...          ...          ...   ...   ...               ...
# 118       964     Pakistan  New Zealand  19.2     1                 8
# 119       964     Pakistan  New Zealand  19.3     0                 9
# 120       964     Pakistan  New Zealand  19.4     2                 9
# 121       964     Pakistan  New Zealand  19.5     1                 9
# 122       964     Pakistan  New Zealand  19.6     1                 9
#
#         city  current_score over ball_no  balls_left  balls_bowled  \
# 0    Central              0    0       1           0             1
# 1    Central              0    0       2           0             2
# 2    Central              0    0       3           0             3
# 3    Central              1    0       4           0             4
# 4    Central              1    0       5           0             5
# ..       ...            ...  ...     ...         ...           ...
# 118     Eden            149   19       2           0           116
# 119     Eden            149   19       3           0           117
# 120     Eden            151   19       4           0           118
# 121     Eden            152   19       5           0           119
# 122     Eden            153   19       6           0           120
#
#      wickets_left
# 0              10
# 1               9
# 2               9
# 3               9
# 4               9
# ..            ...
# 118             2
# 119             1
# 120             1
# 121             1
# 122             1
#
# [51286 rows x 13 columns]

# %%
#calculating current run rate score     
matches['crr'] = (matches['current_score']*6)/matches['balls_bowled']

# %%
matches['runs'].astype(int)
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
#       ..
# 118    1
# 119    0
# 120    2
# 121    1
# 122    1
# Name: runs, Length: 51286, dtype: int64

# %%
groups = matches.groupby('match_id')
match_id = matches['match_id'].unique()
last_five = []
for id in match_id:
    last_five.extend(groups.get_group(id).rolling(window = 30)['runs'].sum().values.tolist())
    # window 30 which means 5*6 = 30 balls in five overs

# %%
last_five
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  28.0,
#  28.0,
#  28.0,
#  28.0,
#  28.0,
#  28.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  26.0,
#  26.0,
#  25.0,
#  25.0,
#  26.0,
#  22.0,
#  16.0,
#  17.0,
#  18.0,
#  19.0,
#  17.0,
#  17.0,
#  15.0,
#  15.0,
#  15.0,
#  16.0,
#  20.0,
#  21.0,
#  15.0,
#  16.0,
#  16.0,
#  16.0,
#  16.0,
#  17.0,
#  16.0,
#  16.0,
#  12.0,
#  12.0,
#  12.0,
#  12.0,
#  13.0,
#  14.0,
#  14.0,
#  20.0,
#  20.0,
#  20.0,
#  20.0,
#  20.0,
#  20.0,
#  19.0,
#  25.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  26.0,
#  22.0,
#  22.0,
#  24.0,
#  23.0,
#  23.0,
#  24.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  21.0,
#  24.0,
#  24.0,
#  24.0,
#  23.0,
#  23.0,
#  29.0,
#  24.0,
#  24.0,
#  25.0,
#  25.0,
#  25.0,
#  24.0,
#  30.0,
#  30.0,
#  28.0,
#  28.0,
#  28.0,
#  27.0,
#  26.0,
#  25.0,
#  25.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  35.0,
#  34.0,
#  34.0,
#  35.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  30.0,
#  30.0,
#  30.0,
#  34.0,
#  33.0,
#  31.0,
#  27.0,
#  27.0,
#  28.0,
#  29.0,
#  29.0,
#  33.0,
#  34.0,
#  35.0,
#  34.0,
#  35.0,
#  34.0,
#  33.0,
#  34.0,
#  31.0,
#  27.0,
#  23.0,
#  23.0,
#  24.0,
#  28.0,
#  28.0,
#  28.0,
#  28.0,
#  28.0,
#  28.0,
#  29.0,
#  29.0,
#  31.0,
#  29.0,
#  29.0,
#  29.0,
#  30.0,
#  26.0,
#  26.0,
#  26.0,
#  27.0,
#  23.0,
#  28.0,
#  28.0,
#  29.0,
#  32.0,
#  33.0,
#  34.0,
#  35.0,
#  35.0,
#  36.0,
#  38.0,
#  38.0,
#  38.0,
#  35.0,
#  38.0,
#  43.0,
#  48.0,
#  49.0,
#  50.0,
#  53.0,
#  54.0,
#  58.0,
#  62.0,
#  62.0,
#  63.0,
#  62.0,
#  63.0,
#  62.0,
#  62.0,
#  62.0,
#  62.0,
#  57.0,
#  56.0,
#  59.0,
#  56.0,
#  56.0,
#  55.0,
#  54.0,
#  54.0,
#  54.0,
#  52.0,
#  52.0,
#  52.0,
#  52.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  33.0,
#  34.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  42.0,
#  42.0,
#  41.0,
#  46.0,
#  47.0,
#  47.0,
#  47.0,
#  52.0,
#  54.0,
#  54.0,
#  55.0,
#  55.0,
#  55.0,
#  55.0,
#  50.0,
#  46.0,
#  42.0,
#  42.0,
#  42.0,
#  41.0,
#  40.0,
#  38.0,
#  38.0,
#  38.0,
#  38.0,
#  42.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  34.0,
#  35.0,
#  37.0,
#  32.0,
#  31.0,
#  31.0,
#  31.0,
#  31.0,
#  30.0,
#  35.0,
#  35.0,
#  40.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  46.0,
#  51.0,
#  51.0,
#  51.0,
#  53.0,
#  55.0,
#  54.0,
#  54.0,
#  54.0,
#  51.0,
#  49.0,
#  53.0,
#  54.0,
#  57.0,
#  57.0,
#  57.0,
#  56.0,
#  56.0,
#  57.0,
#  58.0,
#  61.0,
#  57.0,
#  56.0,
#  50.0,
#  53.0,
#  48.0,
#  48.0,
#  53.0,
#  58.0,
#  61.0,
#  63.0,
#  58.0,
#  57.0,
#  58.0,
#  57.0,
#  56.0,
#  57.0,
#  57.0,
#  60.0,
#  60.0,
#  64.0,
#  60.0,
#  61.0,
#  63.0,
#  64.0,
#  64.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  25.0,
#  23.0,
#  23.0,
#  22.0,
#  21.0,
#  21.0,
#  21.0,
#  22.0,
#  22.0,
#  23.0,
#  23.0,
#  24.0,
#  23.0,
#  22.0,
#  18.0,
#  15.0,
#  16.0,
#  18.0,
#  19.0,
#  19.0,
#  19.0,
#  19.0,
#  21.0,
#  24.0,
#  25.0,
#  25.0,
#  22.0,
#  18.0,
#  19.0,
#  20.0,
#  21.0,
#  22.0,
#  22.0,
#  23.0,
#  24.0,
#  24.0,
#  30.0,
#  29.0,
#  30.0,
#  35.0,
#  39.0,
#  42.0,
#  43.0,
#  44.0,
#  45.0,
#  45.0,
#  48.0,
#  46.0,
#  44.0,
#  44.0,
#  45.0,
#  45.0,
#  43.0,
#  40.0,
#  40.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  43.0,
#  42.0,
#  41.0,
#  41.0,
#  40.0,
#  41.0,
#  42.0,
#  37.0,
#  37.0,
#  36.0,
#  31.0,
#  27.0,
#  25.0,
#  24.0,
#  23.0,
#  23.0,
#  22.0,
#  18.0,
#  18.0,
#  19.0,
#  20.0,
#  19.0,
#  20.0,
#  21.0,
#  21.0,
#  20.0,
#  19.0,
#  19.0,
#  18.0,
#  19.0,
#  16.0,
#  17.0,
#  19.0,
#  23.0,
#  23.0,
#  21.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  36.0,
#  35.0,
#  35.0,
#  36.0,
#  37.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  41.0,
#  46.0,
#  49.0,
#  46.0,
#  40.0,
#  41.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  37.0,
#  31.0,
#  31.0,
#  31.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  29.0,
#  28.0,
#  28.0,
#  25.0,
#  26.0,
#  27.0,
#  27.0,
#  28.0,
#  31.0,
#  32.0,
#  32.0,
#  28.0,
#  28.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  30.0,
#  33.0,
#  33.0,
#  34.0,
#  35.0,
#  35.0,
#  35.0,
#  36.0,
#  37.0,
#  38.0,
#  38.0,
#  41.0,
#  47.0,
#  47.0,
#  47.0,
#  48.0,
#  48.0,
#  53.0,
#  57.0,
#  61.0,
#  64.0,
#  60.0,
#  65.0,
#  61.0,
#  67.0,
#  66.0,
#  63.0,
#  62.0,
#  63.0,
#  64.0,
#  63.0,
#  60.0,
#  62.0,
#  62.0,
#  62.0,
#  61.0,
#  64.0,
#  67.0,
#  70.0,
#  73.0,
#  78.0,
#  76.0,
#  70.0,
#  76.0,
#  77.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  37.0,
#  39.0,
#  43.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  41.0,
#  42.0,
#  44.0,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  44.0,
#  41.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  38.0,
#  35.0,
#  36.0,
#  35.0,
#  34.0,
#  31.0,
#  28.0,
#  27.0,
#  27.0,
#  28.0,
#  29.0,
#  28.0,
#  24.0,
#  23.0,
#  24.0,
#  26.0,
#  26.0,
#  28.0,
#  23.0,
#  22.0,
#  23.0,
#  22.0,
#  21.0,
#  25.0,
#  26.0,
#  26.0,
#  30.0,
#  30.0,
#  31.0,
#  31.0,
#  31.0,
#  30.0,
#  30.0,
#  31.0,
#  32.0,
#  32.0,
#  31.0,
#  32.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  33.0,
#  32.0,
#  30.0,
#  31.0,
#  30.0,
#  30.0,
#  33.0,
#  34.0,
#  35.0,
#  36.0,
#  33.0,
#  32.0,
#  32.0,
#  30.0,
#  30.0,
#  28.0,
#  27.0,
#  28.0,
#  29.0,
#  28.0,
#  28.0,
#  28.0,
#  29.0,
#  31.0,
#  33.0,
#  34.0,
#  35.0,
#  34.0,
#  34.0,
#  39.0,
#  44.0,
#  48.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  18.0,
#  16.0,
#  17.0,
#  21.0,
#  21.0,
#  25.0,
#  27.0,
#  27.0,
#  28.0,
#  30.0,
#  30.0,
#  27.0,
#  27.0,
#  28.0,
#  28.0,
#  29.0,
#  29.0,
#  29.0,
#  29.0,
#  31.0,
#  31.0,
#  32.0,
#  32.0,
#  29.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  28.0,
#  29.0,
#  31.0,
#  32.0,
#  33.0,
#  30.0,
#  31.0,
#  27.0,
#  25.0,
#  24.0,
#  24.0,
#  23.0,
#  24.0,
#  23.0,
#  24.0,
#  24.0,
#  25.0,
#  25.0,
#  29.0,
#  30.0,
#  35.0,
#  33.0,
#  33.0,
#  32.0,
#  33.0,
#  33.0,
#  38.0,
#  43.0,
#  44.0,
#  43.0,
#  47.0,
#  46.0,
#  48.0,
#  49.0,
#  47.0,
#  50.0,
#  49.0,
#  50.0,
#  50.0,
#  50.0,
#  49.0,
#  50.0,
#  49.0,
#  50.0,
#  50.0,
#  50.0,
#  49.0,
#  49.0,
#  45.0,
#  44.0,
#  39.0,
#  39.0,
#  38.0,
#  39.0,
#  39.0,
#  38.0,
#  32.0,
#  27.0,
#  27.0,
#  28.0,
#  25.0,
#  24.0,
#  21.0,
#  19.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  28.0,
#  29.0,
#  29.0,
#  29.0,
#  28.0,
#  28.0,
#  32.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  31.0,
#  32.0,
#  33.0,
#  33.0,
#  35.0,
#  35.0,
#  35.0,
#  36.0,
#  40.0,
#  37.0,
#  38.0,
#  37.0,
#  39.0,
#  39.0,
#  37.0,
#  40.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  39.0,
#  45.0,
#  51.0,
#  52.0,
#  49.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  48.0,
#  48.0,
#  47.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  42.0,
#  42.0,
#  40.0,
#  40.0,
#  37.0,
#  37.0,
#  41.0,
#  43.0,
#  43.0,
#  44.0,
#  45.0,
#  45.0,
#  46.0,
#  46.0,
#  44.0,
#  38.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  44.0,
#  47.0,
#  48.0,
#  49.0,
#  49.0,
#  53.0,
#  54.0,
#  54.0,
#  54.0,
#  55.0,
#  58.0,
#  58.0,
#  62.0,
#  61.0,
#  61.0,
#  61.0,
#  55.0,
#  53.0,
#  53.0,
#  53.0,
#  53.0,
#  53.0,
#  53.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
matches['last_five'] = last_five  # on each match for last 30 balls we get nan values as no sum values for past 30 balls

# %%
matches.head(1)
# Out:
#    match_id batting_team bowling_team  ball  runs  player_dismissed     city  \
# 0         2  West Indies        India   0.1     0                 0  Central
#
#    current_score over ball_no  balls_left  balls_bowled  wickets_left  crr  \
# 0              0    0       1           0             1            10  0.0
#
#    last_five
# 0        NaN

# %%
matches.groupby('match_id')['runs'].sum().reset_index().rename(columns = {'runs':'total_runs'})  # dataframe
# Out:
#      match_id  total_runs
# 0           2          95
# 1           3         150
# 2           4         202
# 3           5         111
# 4           6         191
# ..        ...         ...
# 418       956         180
# 419       957         211
# 420       958         138
# 421       959         222
# 422       964         153
#
# [423 rows x 2 columns]

# %%
final_df = matches.groupby('match_id')['runs'].sum().reset_index().rename(columns = {'runs':'total_runs'}).merge(matches , on ='match_id')  # merge on match_id

# %%
final_df
# Out:
#        match_id  total_runs batting_team bowling_team  ball  runs  \
# 0             2          95  West Indies        India   0.1     0
# 1             2          95  West Indies        India   0.2     0
# 2             2          95  West Indies        India   0.3     0
# 3             2          95  West Indies        India   0.4     1
# 4             2          95  West Indies        India   0.5     0
# ...         ...         ...          ...          ...   ...   ...
# 51281       964         153     Pakistan  New Zealand  19.2     1
# 51282       964         153     Pakistan  New Zealand  19.3     0
# 51283       964         153     Pakistan  New Zealand  19.4     2
# 51284       964         153     Pakistan  New Zealand  19.5     1
# 51285       964         153     Pakistan  New Zealand  19.6     1
#
#        player_dismissed     city  current_score over ball_no  balls_left  \
# 0                     0  Central              0    0       1           0
# 1                     1  Central              0    0       2           0
# 2                     1  Central              0    0       3           0
# 3                     1  Central              1    0       4           0
# 4                     1  Central              1    0       5           0
# ...                 ...      ...            ...  ...     ...         ...
# 51281                 8     Eden            149   19       2           0
# 51282                 9     Eden            149   19       3           0
# 51283                 9     Eden            151   19       4           0
# 51284                 9     Eden            152   19       5           0
# 51285                 9     Eden            153   19       6           0
#
#        balls_bowled  wickets_left       crr  last_five
# 0                 1            10  0.000000        NaN
# 1                 2             9  0.000000        NaN
# 2                 3             9  0.000000        NaN
# 3                 4             9  1.500000        NaN
# 4                 5             9  1.200000        NaN
# ...             ...           ...       ...        ...
# 51281           116             2  7.706897       56.0
# 51282           117             1  7.641026       50.0
# 51283           118             1  7.677966       52.0
# 51284           119             1  7.663866       53.0
# 51285           120             1  7.650000       54.0
#
# [51286 rows x 16 columns]

# %%
final_df = final_df[['batting_team', 'bowling_team','city', 'current_score', 'crr', 'balls_left','wickets_left','last_five','total_runs']]

# %%
final_df.isna().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# crr                  0
# balls_left           0
# wickets_left         0
# last_five        12227
# total_runs           0
# dtype: int64

# %%
final_df.dropna(inplace = True)

# %%
final_df.shape
# Out:
# (39059, 9)

# %%
final_df = final_df.sample(final_df.shape[0])   # shuffling

# %%
final_df.head(20)
# Out:
#        batting_team  bowling_team        city  current_score        crr  \
# 25296      Pakistan     Australia       Dubai             76   6.705882
# 8992      Sri Lanka         India      Punjab            176   9.962264
# 2425     Bangladesh   West Indies       Shere            206  10.474576
# 12772       England      Pakistan         Old             56   8.195122
# 9412        England   New Zealand      Seddon             37   7.400000
# 37373    Bangladesh      Pakistan     Gaddafi             42   5.142857
# 20401   New Zealand    Bangladesh         Bay             61   5.809524
# 1414        England   Afghanistan           R             73   7.551724
# 19053      Pakistan  South Africa       Dubai             51   4.191781
# 26533     Australia  South Africa         New             88   6.683544
# 49642      Pakistan    Bangladesh       Shere            114   6.772277
# 11812   West Indies         India     Central             78   7.428571
# 42233      Pakistan         India        Eden             52   4.952381
# 1925        England     Australia   Melbourne            110   6.285714
# 37796  South Africa       England    Newlands            107   6.420000
# 5865   South Africa   West Indies         New            130  11.641791
# 47127   West Indies       England  Kennington             79   6.405405
# 1448        England   Afghanistan           R            115   7.582418
# 13518      Pakistan    Bangladesh       Shere             26   3.545455
# 1413        England   Afghanistan           R             71   7.473684
#
#        balls_left  wickets_left  last_five  total_runs
# 25296           0             9       39.0         151
# 8992            0             3       35.0         206
# 2425            0             6       55.0         211
# 12772           0             9       48.0         135
# 9412            0             8       37.0         194
# 37373           0             7       24.0         136
# 20401           0             7       20.0         194
# 1414            0             8       45.0         196
# 19053           0             5       26.0          98
# 26533           0             5       29.0         166
# 49642           0             4       27.0         135
# 11812           0             6       26.0         143
# 42233           0             8       25.0         118
# 1925            0             3       21.0         130
# 37796           0             4       24.0         154
# 5865            0             7       60.0         231
# 47127           0             8       23.0         125
# 1448            0             8       39.0         196
# 13518           0             7       18.0         129
# 1413            0             8       44.0         196

# %%
final_df.to_csv('t20_cleandata.csv', index = False)  # saving dataset

# %% [markdown]
# # Creting model and pipeline

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder 
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import StandardScaler 
from sklearn.ensemble import RandomForestRegressor 
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse = False,drop = 'first'),['batting_team' ,'bowling_team','city'])
                     ]
,remainder = 'passthrough')

# %%
trf
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('trf',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['batting_team', 'bowling_team', 'city'])])

# %%
# Total_runs is our y ind the rest is x
x = final_df.drop(columns=['total_runs'])
y = final_df['total_runs']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
pip = Pipeline(steps = [('step1', trf),
                        ('step2',StandardScaler()),
                        ('step3',XGBRegressor(n_estimator = 1000, max_depth = 12, learning_rate = 0.3,random_state = 1)
                                                                  
                                                                     
                                                                  )])

# %%
pip.fit(x_train,y_train)
y_pred = pip.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9868894560731101
# 1.8680182025790275

# %%
pickle.dump(pip,open('pip.pkl_1','wb'))

# %%
list(final_df['city'].unique())
# Out:
# ['Newlands',
#  'Beausejour',
#  'Kensington',
#  'Shere',
#  'Trent',
#  'Wankhede',
#  'Eden',
#  'Dubai',
#  'Warner',
#  'Old',
#  'Kennington',
#  'Pallekele',
#  'The',
#  'Vidarbha',
#  'Zahur',
#  'Adelaide',
#  'New',
#  "Queen's",
#  'SuperSport',
#  'R.Premadasa',
#  'Westpac',
#  'Sydney',
#  'R',
#  "Lord's",
#  'M',
#  'Sophia',
#  'Kingsmead',
#  'Punjab',
#  'Seddon',
#  'Gaddafi',
#  'Sheikh',
#  'Central',
#  'Bay',
#  'Melbourne']

# %%
a = ['Newlands',
 'Beausejour',
 'Kensington',
 'Shere',
 'Trent',
 'Wankhede',
 'Eden',
 'Dubai',
 'Warner',
 'Old',
 'Kennington',
 'Pallekele',
 'The',
 'Vidarbha',
 'Zahur',
 'Adelaide',
 'New',
 "Queen's",
 'SuperSport',
 'R.Premadasa',
 'Westpac',
 'Sydney',
 'R',
 "Lord's",
 'M',
 'Sophia',
 'Kingsmead',
 'Punjab',
 'Seddon',
 'Gaddafi',
 'Sheikh',
 'Central',
 'Bay',
 'Melbourne']

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]
